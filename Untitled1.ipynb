# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,9,1)
downdensity_us0 = [ 0.20975 ,-0.1585 , -0.1075,   0.06 ,    0.03525, -0.11225, -0.12725 , 0.2005 ]
downdensity_them0 = [0.24416442695202523,-0.11392054202026476,-0.12819788412784264,-0.001656679778749592,-0.000638746001610015,-0.12790717800377238,-0.11507742209743668,0.24323402507765088]
updensity_us0 = [0.71725, 0.555  , 0.428 ,  0.3125 , 0.30325 ,0.42475, 0.54375 ,0.7155 ]
updensity_them0 = [0.672158627910119,0.5380678127466911,0.4506603143107202,0.3377682657040423,0.3376604322219041,0.4523022932240122,0.5397174335470422,0.6716648203354689]

plt.plot(x, downdensity_us0, color='r', marker = 'o',label='Qiskit results spin')
plt.plot(x, downdensity_them0, color='r', marker = 'o',label='Googles results spin',linestyle = 'dashed')
plt.plot(x, updensity_us0, color='b', marker = 'o',label='Qiskit results charge')
plt.plot(x, updensity_them0, color='b', marker = 'o',label='Googles results charge',linestyle = 'dashed')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,12,1)
downdensityspread_us0 = [-2.051  , -2.079  , -1.91275, -1.62575, -1.332 ,  -1.043 ,  -0.67575, -0.44425, -0.24175,  0.11025 , 0.362  ]
downdensityspread_them0 = [-2.12490174431193, -2.0632778437655026, -1.881054487802881,-1.6234467608058822,-1.3151665937887984,-0.9873343960673142,-0.6858615521548859,-0.42157070597757007, -0.16810634580135875, 0.09540959245596346 ,0.39881543121970753]
updensityspread_us0 = [5.1965,  5.22 ,   5.87575 ,6.62175, 7.4785 , 8.1465 , 8.86125, 9.32475, 9.61775, 9.59975, 9.304  ]
updensityspread_them0 = [5.086382763459325, 5.261562334459747, 5.86198692389752, 6.674126594523347, 7.460800176405308, 8.155391566597613, 8.787946585418794, 9.295890478583646, 9.58421258031047, 9.580309991135824, 9.32347022356312]

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(x, downdensityspread_us0, color='r', marker = 'o',label='Qiskit results spin')
ax1.plot(x, downdensityspread_them0, color='r', marker = 'o',label='Googles results spin',linestyle = 'dashed')
ax2.plot(x, updensityspread_us0, color='b', marker = 'o',label='Qiskit results charge')
ax2.plot(x, updensityspread_them0, color='b', marker = 'o',label='Googles results charge',linestyle = 'dashed')

a = ax1.plot(x, downdensityspread_us0, color='r', marker = 'o',label='Qiskit results spin')
b = ax1.plot(x, downdensityspread_them0, color='r', marker = 'o',label='Googles results spin',linestyle = 'dashed')
c = ax2.plot(x, updensityspread_us0, color='b', marker = 'o',label='Qiskit results charge')
d = ax2.plot(x, updensityspread_them0, color='b', marker = 'o',label='Googles results charge',linestyle = 'dashed')

e = a + b + c + d
labs = [l.get_label() for l in e]

plt.legend(e, labs)
plt.show()

# %%
[5.075184374999999, 5.2440004150725015, 5.829352209149651, 6.629160887511148, 7.420349426748782, 8.12601189065088, 8.746802542174905, 9.259997834730271, 9.580706005102614, 9.620132819714943, 9.38850325061241] 

[-2.130746875, -2.05741039091095, -1.8367517724314828, -1.524771237758273, -1.1674990681993034, -0.7885772976292165, -0.41358312979199174, -0.045925984268578246, 0.304976157296039, 0.6478662083636781, 0.9579649063727333]
# Out:
# [-2.130746875,
#  -2.05741039091095,
#  -1.8367517724314828,
#  -1.524771237758273,
#  -1.1674990681993034,
#  -0.7885772976292165,
#  -0.41358312979199174,
#  -0.045925984268578246,
#  0.304976157296039,
#  0.6478662083636781,
#  0.9579649063727333]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,12,1)
downdensityspread_us0 = [-2.051  , -2.079  , -1.91275, -1.62575, -1.332 ,  -1.043 ,  -0.67575, -0.44425, -0.24175,  0.11025 , 0.362  ]
downdensityspread_them0 = [-2.130746875, -2.05741039091095, -1.8367517724314828, -1.524771237758273, -1.1674990681993034, -0.7885772976292165, -0.41358312979199174, -0.045925984268578246, 0.304976157296039, 0.6478662083636781, 0.9579649063727333]
updensityspread_us0 = [5.1965,  5.22 ,   5.87575 ,6.62175, 7.4785 , 8.1465 , 8.86125, 9.32475, 9.61775, 9.59975, 9.304  ]
updensityspread_them0 = [5.075184374999999, 5.2440004150725015, 5.829352209149651, 6.629160887511148, 7.420349426748782, 8.12601189065088, 8.746802542174905, 9.259997834730271, 9.580706005102614, 9.620132819714943, 9.38850325061241] 


fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(x, downdensityspread_us0, color='r', marker = 'o',label='Qiskit results spin')
ax1.plot(x, downdensityspread_them0, color='r', marker = 'o',label='Googles results spin',linestyle = 'dashed')
ax2.plot(x, updensityspread_us0, color='b', marker = 'o',label='Qiskit results charge')
ax2.plot(x, updensityspread_them0, color='b', marker = 'o',label='Googles results charge',linestyle = 'dashed')

a = ax1.plot(x, downdensityspread_us0, color='r', marker = 'o',label='Qiskit results spin')
b = ax1.plot(x, downdensityspread_them0, color='r', marker = 'o',label='Googles results spin',linestyle = 'dashed')
c = ax2.plot(x, updensityspread_us0, color='b', marker = 'o',label='Qiskit results charge')
d = ax2.plot(x, updensityspread_them0, color='b', marker = 'o',label='Googles results charge',linestyle = 'dashed')

e = a + b + c + d
labs = [l.get_label() for l in e]

plt.legend(e, labs)
plt.show()
